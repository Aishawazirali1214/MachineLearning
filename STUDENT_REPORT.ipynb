# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow import keras
from keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import skew, kurtosis,f_oneway,chi2_contingency
from statistics import variance
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
from fractions import Fraction as fr
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,ConfusionMatrixDisplay,mean_absolute_error,roc_curve,auc, recall_score, f1_score, precision_score
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn import metrics #for evaluation of the model
from sklearn.neighbors import KNeighborsRegressor,KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import roc_curve, auc

# %%
df=pd.read_csv('/content/exams.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['Total Score']=df['writing score']+df['reading score']+df['math score']

# %%
df[['writing score','reading score','math score','Total Score']]
# Out:
#      writing score  reading score  math score  Total Score
# 0               78             70          59          207
# 1               87             93          96          276
# 2               77             76          57          210
# 3               63             70          70          203
# 4               86             85          83          254
# ..             ...            ...         ...          ...
# 995             71             77          77          225
# 996             66             66          80          212
# 997             86             86          67          239
# 998             62             72          80          214
# 999             45             47          58          150
#
# [1000 rows x 4 columns]

# %%
# plt.figure(figsize=(12,6))
# sns.boxplot(data=df,x='Total Score',y='Gender')
# plt.xlabel("Total score of each Race")
# plt.ylabel("Race Group")
# plt.title("Distribution and Variation of Race and Total Score of Subjects")
# plt.show()

# %%
df['Total Score'].max()
# Out:
# 300

# %%
df['Total Score'].min()
# Out:
# 60

# %%
df['Status'] = pd.cut(df['Total Score'], bins=[0, 100, 200,250, float('inf')], labels=['Insufficient', 'Good', 'Very Good','Excellent'])
df.Status
# Out:
# 0      Very Good
# 1      Excellent
# 2      Very Good
# 3      Very Good
# 4      Excellent
#          ...
# 995    Very Good
# 996    Very Good
# 997    Very Good
# 998    Very Good
# 999         Good
# Name: Status, Length: 1000, dtype: category
# Categories (4, object): ['Insufficient' < 'Good' < 'Very Good' < 'Excellent']

# %%
df.Status.value_counts()
# Out:
# Status
# Very Good       417
# Good            414
# Excellent       160
# Insufficient      9
# Name: count, dtype: int64

# %%
df['Total percentage']=((df['writing score']+df['reading score']+df['math score'])/3).round()
df['Total percentage']
# Out:
# 0      69.0
# 1      92.0
# 2      70.0
# 3      68.0
# 4      85.0
#        ...
# 995    75.0
# 996    71.0
# 997    80.0
# 998    71.0
# 999    50.0
# Name: Total percentage, Length: 1000, dtype: float64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
df['gender']=lc.fit_transform(df['gender'])
df['race/ethnicity']=lc.fit_transform(df['race/ethnicity'])
df['parental level of education']=lc.fit_transform(df['parental level of education'])
df['lunch']=lc.fit_transform(df['lunch'])
df['test preparation course']=lc.fit_transform(df['test preparation course'])
df['Status']=lc.fit_transform(df['Status'])
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               3                            4      1
# 1         1               3                            0      1
# 2         0               3                            4      0
# 3         1               1                            4      0
# 4         0               3                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            4      1
# 996       1               2                            4      1
# 997       0               0                            2      1
# 998       1               4                            2      1
# 999       1               3                            2      1
#
#      test preparation course  math score  reading score  writing score  \
# 0                          0          59             70             78
# ...

# %%
#training part
from sklearn.model_selection import train_test_split
# x=df.drop(['Total percentage','Total Score','Status'],axis=1)
# y=df['Status']
x=df.drop(['Total Score'],axis=1)
y=df['Total Score']
# from sklearn.model_selection import train_test_split
# x=df.drop(['Total percentage'],axis=1)
# y=df['Total percentage']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
model=LogisticRegression(solver='liblinear',random_state=0)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
predication = model.predict(x_test)

# %%
predication
# Out:
# array([223, 223, 177, 144, 226, 182, 195, 243, 185, 231, 264, 217, 214,
#        189, 223, 196, 223, 223, 185, 177, 202, 192, 234, 193, 223, 191,
#        192, 168, 226, 264, 233, 172, 238, 262, 262, 173, 168, 201, 223,
#        223, 191, 213, 201, 160, 216, 229, 213, 192, 196, 196, 229, 188,
#        151, 213, 173, 203, 247, 258, 268, 189, 239, 264, 223, 216, 224,
#        264, 223, 223, 192, 245, 235, 237, 182, 203, 209, 223, 264, 229,
#        193, 213, 159, 263, 230, 121, 234, 159, 266, 184, 196, 188, 168,
#        192, 230, 210, 196, 213, 202, 190, 226, 209, 230, 263, 188, 172,
#        139, 264, 177, 258, 223, 213, 249, 155, 230, 182, 223, 196, 253,
#        249, 223, 202, 264, 263, 203, 196, 242, 182, 226, 185, 160, 192,
#        196, 229, 235, 221, 168, 191, 264, 223, 230, 159, 183, 167, 160,
#        196, 185, 203, 184, 203, 196, 234, 195, 224, 227, 239, 160, 223,
#        238, 234, 235, 236, 262, 223, 194, 188, 258, 264, 177, 155, 177,
# ...

# %%
y_test
# Out:
# 993    237
# 859    244
# 298    147
# 553    144
# 672    211
#       ...
# 679    214
# 722    167
# 215    250
# 653    283
# 150    198
# Name: Total Score, Length: 200, dtype: int64

# %%
difference=abs(predication-y_test)

# %%
difference.mean()
# Out:
# 15.92

# %%
def mathsuccess(x):
    if (x > 80) :
        return("succesful")

    elif(66 < x <80) :
        return("to improve")
    else:
        return("unsuccessful")

df["math_success_scala"] = df.apply(lambda x: mathsuccess(x["math_score"]), axis = 1)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-22ff52ee15d2> in <cell line: 10>()
#       8         return("unsuccessful")
#       9
# ...

# %%
def mathsuccess(x):
    if (x > 80) :
        return("succesful")

    elif(66 < x <80) :
        return("to improve")
    else:
        return("unsuccessful")

# Assuming 'math score' is the correct column name
# Replace 'math score' with the actual column name if different
df["math_success_scala"] = df.apply(lambda x: mathsuccess(x["math score"]), axis = 1)
print(df)
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               3                            4      1
# 1         1               3                            0      1
# 2         0               3                            4      0
# 3         1               1                            4      0
# 4         0               3                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            4      1
# 996       1               2                            4      1
# 997       0               0                            2      1
# 998       1               4                            2      1
# 999       1               3                            2      1
#
#      test preparation course  math score  reading score  writing score  \
# 0                          0          59             70             78
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
